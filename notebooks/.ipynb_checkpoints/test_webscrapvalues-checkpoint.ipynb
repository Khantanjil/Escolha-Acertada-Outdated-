# %%
from bs4 import BeautifulSoup
import requests
import stringmeth

r = requests.get("http://www.escolhaacertada.pt/pt-PT/Imoveis/-/-/-/-/-/-/-/-/-/-/-/-/0/0/20/1/1",
                headers={
                    'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'
                })
c = r.content

soup = BeautifulSoup(c, "html.parser")
all = soup.find_all("div", {"class":"row"})
l = []
for i in all:
    d = {}
    i_list = soup.find_all("i", class_="icon-area")
    for i in i_list:
        print(i.parent.text)
# Out:
# 45 m2
# 40 m2
# 73 m2
# 53 m2
# 65 m2
# 60 m2
# 100 m2
# 62 m2
# 173 m2
# 200 m2
# 240 m2
# 180 m2
# 785 m2
# 690 m2
# 167 m2
# -
# 305 m2
# 294 m2
# 1.000 m2
# 11 m2
# 45 m2
# 40 m2
# 73 m2
# 53 m2
# 65 m2
# 60 m2
# 100 m2
# 62 m2
# 173 m2
# 200 m2
# 240 m2
# 180 m2
# 785 m2
# 690 m2
# 167 m2
# -
# 305 m2
# 294 m2
# 1.000 m2
# 11 m2
# 45 m2
# 40 m2
# 73 m2
# 53 m2
# 65 m2
# 60 m2
# 100 m2
# 62 m2
# 173 m2
# 200 m2
# 240 m2
# 180 m2
# 785 m2
# 690 m2
# 167 m2
# -
# 305 m2
# 294 m2
# 1.000 m2
# 11 m2
# 45 m2
# 40 m2
# 73 m2
# 53 m2
# 65 m2
# 60 m2
# 100 m2
# 62 m2
# 173 m2
# 200 m2
# 240 m2
# 180 m2
# 785 m2
# 690 m2
# 167 m2
# -
# 305 m2
# 294 m2
# 1.000 m2
# 11 m2
# 45 m2
# 40 m2
# 73 m2
# 53 m2
# 65 m2
# 60 m2
# 100 m2
# 62 m2
# 173 m2
# 200 m2
# 240 m2
# 180 m2
# 785 m2
# 690 m2
# 167 m2
# -
# 305 m2
# 294 m2
# 1.000 m2
# 11 m2
# 45 m2
# 40 m2
# 73 m2
# 53 m2
# 65 m2
# 60 m2
# 100 m2
# 62 m2
# 173 m2
# 200 m2
# 240 m2
# 180 m2
# 785 m2
# 690 m2
# 167 m2
# -
# 305 m2
# 294 m2
# 1.000 m2
# 11 m2

# %%
import pandas
df = pandas.DataFrame(l)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
